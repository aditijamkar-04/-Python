# %% [markdown]
# # Easy–Medium

# %%
3 ^ 5 & -9 | 2
# Out:
# 6

# %%
7 & 12 ^ 5
# Out:
# 1

# %%
15 | 6 ^ 3
# Out:
# 15

# %%
8 ^ 4 & 3
# Out:
# 8

# %%
10 | 5 & 7
# Out:
# 15

# %%
14 ^ 9 | 2
# Out:
# 7

# %%
25 & 17 ^ 8
# Out:
# 25

# %%
31 | 12 & 5
# Out:
# 31

# %%
18 ^ 7 | 4
# Out:
# 21

# %%
22 & 13 ^ 9
# Out:
# 13

# %% [markdown]
# # With Negative Numbers

# %%
5 ^ -3 & 7
# Out:
# 0

# %%
-8 | 6 ^ 2
# Out:
# -4

# %%
-5 & 12 | 3
# Out:
# 11

# %%
9 ^ -4 & 15
# Out:
# 5

# %%
-10 ^ 7 | 5
# Out:
# -11

# %%
-12 & 9 ^ 4
# Out:
# 4

# %%
3 | -6 & 11
# Out:
# 11

# %%
-15 ^ 8 & 7
# Out:
# -15

# %%
14 | -9 ^ 5
# Out:
# -2

# %%
-20 & 13 | 6
# Out:
# 14

# %% [markdown]
# # Mixed Operators

# %%
7 ^ 12 & 5 | 3
# Out:
# 3

# %%
16 | 9 ^ 4 & 7
# Out:
# 29

# %%
25 & 14 ^ 11 | 2
# Out:
# 3

# %%
18 ^ 6 | 9 & 5
# Out:
# 21

# %%
31 & 15 ^ 8 | 4
# Out:
# 7

# %%
11 | 22 & 7 ^ 3
# Out:
# 15

# %%
13 ^ 5 & 10 | 1
# Out:
# 13

# %%
24 & 19 | 7 ^ 2
# Out:
# 21

# %%
17 ^ 12 & 9 | 6
# Out:
# 31

# %%
29 | 14 ^ 3 & 5
# Out:
# 31

# %% [markdown]
# # With Bit Shifts

# %%
5 << 2 ^ 3
# Out:
# 23

# %%
16 >> 1 | 5
# Out:
# 13

# %%
7 << 1 & 12
# Out:
# 12

# %%
20 >> 2 ^ 6
# Out:
# 3

# %%
3 << 3 | 7
# Out:
# 31

# %%
64 >> 3 & 5
# Out:
# 0

# %%
9 << 2 ^ 14
# Out:
# 42

# %%
48 >> 2 | 3
# Out:
# 15

# %%
11 << 1 & 15
# Out:
# 6

# %%
100 >> 4 ^ 9
# Out:
# 15

# %%
(-5 ^ 7) & 12 | 3
# Out:
# 15

# %%
15 ^ (8 & -4) | 6
# Out:
# 7

# %%
(-12 | 5) ^ 9 & 7
# Out:
# -12

# %%
(25 & 18) ^ (-6 | 3)
# Out:
# -21

# %%
(~5 & 15) ^ 8
# Out:
# 2

# %%
(~12 | 7) & 9
# Out:
# 1

# %%
(7 << 2) ^ (-9 & 15)
# Out:
# 27

# %%
(-16 >> 2) | 5 ^ 3
# Out:
# -2

# %%
(31 & ~7) ^ 12
# Out:
# 20

# %%
(~10 & 31) | (6 ^ 3)
# Out:
# 21

# %%
3 ^ 5 & 6 | 2
# Out:
# 7

# %%
8 | 4 ^ 2 & 7
# Out:
# 14

# %%
15 & 9 ^ 3 | 1
# Out:
# 11

# %%
7 | 12 & 5 ^ 2
# Out:
# 7

# %%
20 ^ 10 & 7 | 4
# Out:
# 22
