# %% [markdown]
# # Time Complexity

# %%
def print_numbers(n):
    for i in range(n):
        print(i)           #time complexity=O(n)
                           #Space Complexity=O(1)

# %%
def print_first(arr):
    print(arr[0])                  #Time Complexity=O(1)
                                   #Space Complexity=O(1)
