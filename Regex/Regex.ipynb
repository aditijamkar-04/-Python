# %% [markdown]
# # Regex

# %%
# !pip install regex

# %%
import re

# %%
string="fan"
pattern="."
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 1), match='f'>

# %%
string[0:1]
# Out:
# 'f'

# %%
string="fan"
pattern=".."
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 2), match='fa'>

# %%
string="fan"
pattern="..."
print(re.match(pattern,string))
# Out:
# <re.Match object; span=(0, 3), match='fan'>

# %%
string="aaaaaa"
pattern="a*"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 6), match='aaaaaa'>

# %%
string="bbbbbb"
pattern="a*"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
string="bbbbbb"
pattern="a+"
print(re.match(pattern, string))
# Out:
# None

# %%
string="aaaaaa"
pattern="a+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 6), match='aaaaaa'>

# %%
string="abababa"
pattern="[a]"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
string="abababa"
pattern="[ab]"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
string="bababa"
pattern="[ab]"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 1), match='b'>

# %%
string="abababa"
pattern="[ab]+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 7), match='abababa'>

# %%
string="abababa"
pattern="[a]+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
string="abababa"
pattern="ab+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 2), match='ab'>

# %%
string="abababa"
pattern="[ab]+"
print(re.findall(pattern, string))
# Out:
# ['abababa']

# %%
string="abababa"
pattern="[ab]*"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 7), match='abababa'>

# %%
string="abababbbbbbbb"
pattern="[b]+"
print(re.findall(pattern,string))
# Out:
# ['b', 'b', 'bbbbbbbb']

# %%
string="abababbbbbbbb"
pattern="[b]*"
print(re.findall(pattern,string))
# Out:
# ['', 'b', '', 'b', '', 'bbbbbbbb', '']

# %%
string="abcdefghijklmnopqrstuvwxyz"
pattern="[a-z]+"
print(re.findall(pattern, string))
# Out:
# ['abcdefghijklmnopqrstuvwxyz']

# %%
string="abcdefghijklmnopqrstuvwxyz"
pattern="[a-z]+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 26), match='abcdefghijklmnopqrstuvwxyz'>

# %%
string="abcdefghijklmnopqrstuvwxyz"
pattern="[a-z]*"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 26), match='abcdefghijklmnopqrstuvwxyz'>

# %%
string="python is a simple language and Python is vast"
pattern="python"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
string="python is a simple language and Python is vast"
pattern="python"
print(re.findall(pattern, string))
# Out:
# ['python']

# %%
string="python is a simple language and Python is vast"
pattern="python*"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
string="python is a simple language and Python is vast"
pattern="python+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
string="python is a simple language and Python is vast"
pattern="[a-zA-Z]+"
print(re.findall(pattern, string))
# Out:
# ['python', 'is', 'a', 'simple', 'language', 'and', 'Python', 'is', 'vast']

# %%
string="python is a simple language and Python is vast"
pattern="[python|Python]"
print(re.findall(pattern, string))
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', 'p', 'n', 'n', 'P', 'y', 't', 'h', 'o', 'n', 't']

# %%
string="python is a simple language and Python is vast"
pattern="python|Python"
print(re.findall(pattern, string))
# Out:
# ['python', 'Python']

# %%
string="I have 12 apples and 20 books "
pattern="[0-9]+"
print(re.findall(pattern, string))
# Out:
# ['12', '20']

# %%
string="juleus ceaser died in 20 oct 1945"
pattern="\d+"
print(re.findall(pattern, string))
# Out:
# ['20', '1945']

# %%
string="i have $12.56"
pattern="/d"
print(re.findall(pattern, string))
# Out:
# []

# %%
string="i have $12.56"
pattern="/d+"
print(re.findall(pattern, string))
# Out:
# []

# %%
string="mayur@"
pattern="[a-z]+"
print(re.findall(pattern, string))
# Out:
# ['mayur']

# %%
string="mayur@"
pattern="[a-z]+\@"
print(re.findall(pattern, string))
# Out:
# ['mayur@']

# %%
string="i have $12.56"
pattern="\$/d+"
print(re.findall(pattern, string))
# Out:
# []

# %%
string="i have $12.56"
pattern="\d+"
print(re.findall(pattern, string))
# Out:
# ['12', '56']

# %%
string="i have $12.56"
pattern="/d+"
print(re.match(pattern, string))
# Out:
# None

# %%
string="i have $12.56"
pattern="\$\d+\./d+"
print(re.findall(pattern, string))
# Out:
# []

# %%
string="i have $12.56"
pattern="\$\d+\.\d+"
print(re.findall(pattern, string))
# Out:
# ['$12.56']

# %%
string="$123"
pattern="\$\d+"
print(re.findall(pattern, string))
# Out:
# ['$123']

# %%
string="$123.64"
pattern="\$\d+\.\d+"
print(re.findall(pattern, string))
# Out:
# ['$123.64']

# %%
string="i have $12.56"
pattern="\$\d+\.\d+"
print(re.match(pattern, string))
# Out:
# None

# %%
string="$123.64"
pattern="\$\d+\.\d+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 7), match='$123.64'>

# %%
string="mayur63587@gmail.com"
pattern="[a-z0-9]+"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 10), match='mayur63587'>

# %%
string="mayur63587@gmail.com"
pattern="[a-z0-9]+\@"
print(re.match(pattern, string))
# Out:
# <re.Match object; span=(0, 11), match='mayur63587@'>

# %%
string="mayur63587@gmail.com"
pattern="[a-z0-9]+\@[a-z]+\.[a-z]+"
print(re.findall(pattern, string))
# Out:
# ['mayur63587@gmail.com']

# %%
string="mayur.iitb67.nic.ac.in"
pattern="[a-z]+\.[a-z0-9]+\.[a-z]+\.[a-z]+\.[a-z]+"
print(re.findall(pattern, string))
# Out:
# ['mayur.iitb67.nic.ac.in']

# %%
string="<HTML>"
pattern="\<[A-Z]+\>"
print(re.findall(pattern, string))
# Out:
# ['<HTML>']

# %%
string="i have a pinapple"
pattern="[a-z]+\ [a-z]+\ [a-z]+\ [a-z]+"
print(re.findall(pattern, string))
# Out:
# ['i have a pinapple']

# %%
string="i have a pinapple"
pattern="pinapple"
print(re.findall(pattern, string))
# Out:
# ['pinapple']

# %%
string="i have a apple and pineapple"
pattern=r"\b\w+\s+and\s+\w+\b"
print(re.findall(pattern,string))
# Out:
# ['apple and pineapple']

# %%
string="i have a aple and pinapple"
pattern="[apple|pinapple]+"
print(re.findall(pattern, string))      # dcorrection needed
# Out:
# ['i', 'a', 'e', 'a', 'aple', 'an', 'pinapple']

# %%
string="abcdefg890216"
pattern="\w+"
print(re.findall(pattern, string))
# Out:
# ['abcdefg890216']

# %%
string="abcdefg890216#%$%$%"
pattern="\W+"
print(re.findall(pattern, string))
# Out:
# ['#%$%$%']

# %%
string="mayur63587@gmail.com"
pattern="\w+"
print(re.findall(pattern, string))
# Out:
# ['mayur63587', 'gmail', 'com']

# %%
string="mayur63587@gmail.com"
pattern="\w+\W+\w+\W+\w+"
print(re.findall(pattern, string))
# Out:
# ['mayur63587@gmail.com']

# %%
string="mayur63587@gmail.com"
pattern="\w+\@\w+\.\w+"
print(re.findall(pattern, string))
# Out:
# ['mayur63587@gmail.com']

# %%
string="mayur63587@gmail.com,mayur.iitb67.nic.ac.in"
pattern="\w+\@\w+\.\w+\,\w+\.\w+\.\w+\.\w+\.\w+"
print(re.findall(pattern, string))
# Out:
# ['mayur63587@gmail.com,mayur.iitb67.nic.ac.in']
